# %%
dl20=(at6923 at6929 at7143 at8285 at9104 at9336 at9503 at9578 at9744 at9762 at9806 at9830 at9847 at9852 at9879 at9883 at9900)

# %%
dl20=(at9879)

# %%
chmod u+w input/*
cp -L ../assembly-and-annotation/output/04_analyses_with_fixed_at9879/prep_for_decision_making/*.scaffolds-v2.3_liftoff_polished.gff3_polished.fix.gff3 input/

# %%
#cp input/at9879.augustus.gff input/at9879.augustus-liftoff.gff
blsl liftoff-gff3 input/at9879.augustus-liftoff.gff | \
    awk 'BEGIN{IFS=OFS="\t"}$0 ~ /^#/{print $0}$0 !~ /^#/{print $1, "AUGUSTUS", $3, $4, $5, $6, $7, $8, $9}' \
    >input/at9879.augustus.gff

# %%
for acc in "${dl20[@]}"
do

    echo
    echo
    echo ${acc}
    grep 'Note=protein_coding_gene' input/${acc}.scaffolds-v2.3_liftoff_polished.gff3_polished.fix.gff3  | grep -Po "\tID=[^;]+" | cut -f 2 -d = >input/${acc}_tairpconly.txt 
    grep -f input/${acc}_tairpconly.txt input/${acc}.scaffolds-v2.3_liftoff_polished.gff3_polished.fix.gff3 > input/${acc}.liftoff.protonly.gff

    files=( input/${acc}.augustus.gff  input/${acc}.liftoff.protonly.gff input/${acc}.pasa.fix.gff input/${acc}.tama-v2.fix.gff)
    
    for file in "${files[@]}"
    do
        (head -n 1 $file | grep -q '^##gff-version') || sed -i -e '1 i\##gff-version 3' $file
    done
    cat "${files[@]}" |
        sortBed -i - |
        mergeBed -i - -s -c 7 -o distinct >input/${acc}_loci.bed
        
    
    grep $acc ../assembly-and-annotation/output/04_analyses_with_fixed_at9879/prep_for_decision_making/All_nlrs_list.txt | awk '{printf("ID=%s$\n",  $3)}' | sort -u -o ${acc}.nlraugids.txt
    grep -f ${acc}.nlraugids.txt input/${acc}.augustus.gff  |
        sortBed -i - |
        intersectBed -wa -a <(awk 'BEGIN{IFS=OFS="\t"}{print $1, $2, $3, ".", "0", $4}' < input/${acc}_loci.bed) -b - -s |
        awk 'BEGIN{IFS=OFS="\t"}{print $1, $2, $3, $6}' > input/${acc}_nlrloci.bed
    
    python3 gffuuuu.py \
        --sad output/${acc}_sad.gff3 \
        --decisions output/${acc}_decisions.bed \
        --happy output/${acc}_happy.gff3 \
        --loci input/${acc}_loci.bed \
        "${files[@]}"
    
    rm -fr ~/public_html/gffuuu/${acc}/
    mkdir -p ~/public_html/gffuuu/${acc}/
    blsl genigvjs --outdir ~/public_html/gffuuu/${acc}/  \
                --reference ~/dl20/assembly-and-annotation/output/01_assembly/01_pansn-named/${acc}.scaffolds-v2.3.fasta \
                "${files[@]}" \
                output/${acc}_sad.gff3 \
                output/${acc}_decisions.bed \
                output/${acc}_happy.gff3
done
# Out:
# at6923
# loci at input/at6923_loci.bed
# N loci: 33672
# Added 32234 genes from input/at6923.augustus.gff (0 missing)
# Added 26966 genes from input/at6923.liftoff.protonly.gff (0 missing)
# Added 14640 genes from input/at6923.pasa.fix.gff (0 missing)
# Added 16832 genes from input/at6923.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	11133
# only_aug	6981
# aug_liftoff_cds_agree_use_liftoff	5303
# aug_liftoff_cds_disagree_use_aug	3313
# only_liftoff	1926
# TOO_HARD	1677
# pasa_liftoff_cds_agree_use_pasa	1549
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	949
# pasa_cds_different_use_pasa	853
# aug_pasa_cds_agree_use_pasa	534
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	85
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	55
#
#
# at6929
# loci at input/at6929_loci.bed
# N loci: 33410
# Added 31940 genes from input/at6929.augustus.gff (0 missing)
# Added 26842 genes from input/at6929.liftoff.protonly.gff (0 missing)
# Added 14185 genes from input/at6929.pasa.fix.gff (0 missing)
# Added 16128 genes from input/at6929.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	10898
# only_aug	6825
# aug_liftoff_cds_agree_use_liftoff	5672
# aug_liftoff_cds_disagree_use_aug	3434
# only_liftoff	1945
# TOO_HARD	1522
# pasa_liftoff_cds_agree_use_pasa	1457
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	788
# pasa_cds_different_use_pasa	766
# aug_pasa_cds_agree_use_pasa	557
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	58
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	49
#
#
# at7143
# loci at input/at7143_loci.bed
# N loci: 33570
# Added 32149 genes from input/at7143.augustus.gff (0 missing)
# Added 26927 genes from input/at7143.liftoff.protonly.gff (0 missing)
# Added 14468 genes from input/at7143.pasa.fix.gff (0 missing)
# Added 16610 genes from input/at7143.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	10994
# only_aug	7000
# aug_liftoff_cds_agree_use_liftoff	5458
# aug_liftoff_cds_disagree_use_aug	3270
# only_liftoff	1935
# TOO_HARD	1576
# pasa_liftoff_cds_agree_use_pasa	1565
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	978
# pasa_cds_different_use_pasa	828
# aug_pasa_cds_agree_use_pasa	542
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	69
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	49
#
#
# at8285
# loci at input/at8285_loci.bed
# N loci: 33719
# Added 32306 genes from input/at8285.augustus.gff (0 missing)
# Added 26881 genes from input/at8285.liftoff.protonly.gff (0 missing)
# Added 13779 genes from input/at8285.pasa.fix.gff (0 missing)
# Added 15553 genes from input/at8285.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	10494
# only_aug	7187
# aug_liftoff_cds_agree_use_liftoff	6087
# aug_liftoff_cds_disagree_use_aug	3528
# only_liftoff	1912
# pasa_liftoff_cds_agree_use_pasa	1523
# TOO_HARD	1395
# pasa_cds_different_use_pasa	777
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	758
# aug_pasa_cds_agree_use_pasa	491
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	61
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	48
#
#
# at9104
# loci at input/at9104_loci.bed
# N loci: 33698
# Added 32144 genes from input/at9104.augustus.gff (0 missing)
# Added 26968 genes from input/at9104.liftoff.protonly.gff (0 missing)
# Added 14692 genes from input/at9104.pasa.fix.gff (0 missing)
# Added 16757 genes from input/at9104.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	11165
# only_aug	6952
# aug_liftoff_cds_agree_use_liftoff	5315
# aug_liftoff_cds_disagree_use_aug	3405
# only_liftoff	1935
# TOO_HARD	1602
# pasa_liftoff_cds_agree_use_pasa	1597
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	791
# pasa_cds_different_use_pasa	774
# aug_pasa_cds_agree_use_pasa	619
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	66
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	46
#
#
# at9336
# loci at input/at9336_loci.bed
# N loci: 34308
# Added 32798 genes from input/at9336.augustus.gff (0 missing)
# Added 26893 genes from input/at9336.liftoff.protonly.gff (0 missing)
# Added 14640 genes from input/at9336.pasa.fix.gff (0 missing)
# Added 16709 genes from input/at9336.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	11133
# only_aug	7669
# aug_liftoff_cds_agree_use_liftoff	5215
# aug_liftoff_cds_disagree_use_aug	3398
# only_liftoff	1992
# pasa_liftoff_cds_agree_use_pasa	1621
# TOO_HARD	1533
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	890
# pasa_cds_different_use_pasa	800
# aug_pasa_cds_agree_use_pasa	562
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	65
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	51
#
#
# at9503
# loci at input/at9503_loci.bed
# N loci: 33506
# Added 32072 genes from input/at9503.augustus.gff (0 missing)
# Added 26974 genes from input/at9503.liftoff.protonly.gff (0 missing)
# Added 14196 genes from input/at9503.pasa.fix.gff (0 missing)
# Added 16383 genes from input/at9503.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	10784
# only_aug	6928
# aug_liftoff_cds_agree_use_liftoff	5562
# aug_liftoff_cds_disagree_use_aug	3341
# only_liftoff	1957
# TOO_HARD	1658
# pasa_liftoff_cds_agree_use_pasa	1516
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	1031
# pasa_cds_different_use_pasa	799
# aug_pasa_cds_agree_use_pasa	525
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	71
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	48
#
#
# at9578
# loci at input/at9578_loci.bed
# N loci: 33621
# Added 32110 genes from input/at9578.augustus.gff (0 missing)
# Added 26913 genes from input/at9578.liftoff.protonly.gff (0 missing)
# Added 14825 genes from input/at9578.pasa.fix.gff (0 missing)
# Added 17243 genes from input/at9578.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	11202
# only_aug	6908
# aug_liftoff_cds_agree_use_liftoff	5027
# aug_liftoff_cds_disagree_use_aug	3279
# only_liftoff	1902
# TOO_HARD	1825
# pasa_liftoff_cds_agree_use_pasa	1599
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	1015
# pasa_cds_different_use_pasa	858
# aug_pasa_cds_agree_use_pasa	582
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	93
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	54
#
#
# at9744
# loci at input/at9744_loci.bed
# N loci: 34000
# Added 32498 genes from input/at9744.augustus.gff (0 missing)
# Added 26999 genes from input/at9744.liftoff.protonly.gff (0 missing)
# Added 14827 genes from input/at9744.pasa.fix.gff (0 missing)
# Added 17087 genes from input/at9744.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	11360
# only_aug	7230
# aug_liftoff_cds_agree_use_liftoff	5092
# aug_liftoff_cds_disagree_use_aug	3335
# only_liftoff	1957
# TOO_HARD	1695
# pasa_liftoff_cds_agree_use_pasa	1569
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	944
# pasa_cds_different_use_pasa	814
# aug_pasa_cds_agree_use_pasa	566
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	52
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	50
#
#
# at9762
# loci at input/at9762_loci.bed
# N loci: 33739
# Added 32306 genes from input/at9762.augustus.gff (0 missing)
# Added 26872 genes from input/at9762.liftoff.protonly.gff (0 missing)
# Added 14085 genes from input/at9762.pasa.fix.gff (0 missing)
# Added 16157 genes from input/at9762.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	10652
# only_aug	7174
# aug_liftoff_cds_agree_use_liftoff	5621
# aug_liftoff_cds_disagree_use_aug	3539
# only_liftoff	1953
# TOO_HARD	1565
# pasa_liftoff_cds_agree_use_pasa	1488
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	820
# pasa_cds_different_use_pasa	808
# aug_pasa_cds_agree_use_pasa	600
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	76
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	48
#
#
# at9806
# loci at input/at9806_loci.bed
# N loci: 33132
# Added 31675 genes from input/at9806.augustus.gff (0 missing)
# Added 26962 genes from input/at9806.liftoff.protonly.gff (0 missing)
# Added 13998 genes from input/at9806.pasa.fix.gff (0 missing)
# Added 15780 genes from input/at9806.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	10727
# only_aug	6574
# aug_liftoff_cds_agree_use_liftoff	5874
# aug_liftoff_cds_disagree_use_aug	3537
# only_liftoff	1961
# pasa_liftoff_cds_agree_use_pasa	1530
# TOO_HARD	1376
# pasa_cds_different_use_pasa	766
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	740
# aug_pasa_cds_agree_use_pasa	462
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	83
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	50
#
#
# at9830
# loci at input/at9830_loci.bed
# N loci: 33496
# Added 31933 genes from input/at9830.augustus.gff (0 missing)
# Added 26860 genes from input/at9830.liftoff.protonly.gff (0 missing)
# Added 14338 genes from input/at9830.pasa.fix.gff (0 missing)
# Added 16203 genes from input/at9830.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	11020
# only_aug	6848
# aug_liftoff_cds_agree_use_liftoff	5610
# aug_liftoff_cds_disagree_use_aug	3501
# only_liftoff	1969
# pasa_liftoff_cds_agree_use_pasa	1535
# TOO_HARD	1445
# pasa_cds_different_use_pasa	737
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	666
# aug_pasa_cds_agree_use_pasa	541
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	70
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	48
#
#
# at9847
# loci at input/at9847_loci.bed
# N loci: 33564
# Added 32154 genes from input/at9847.augustus.gff (0 missing)
# Added 26859 genes from input/at9847.liftoff.protonly.gff (0 missing)
# Added 14728 genes from input/at9847.pasa.fix.gff (0 missing)
# Added 16943 genes from input/at9847.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	11150
# only_aug	7006
# aug_liftoff_cds_agree_use_liftoff	5105
# aug_liftoff_cds_disagree_use_aug	3269
# only_liftoff	1932
# TOO_HARD	1652
# pasa_liftoff_cds_agree_use_pasa	1612
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	1025
# pasa_cds_different_use_pasa	852
# aug_pasa_cds_agree_use_pasa	555
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	74
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	52
#
#
# at9852
# loci at input/at9852_loci.bed
# N loci: 32924
# Added 31642 genes from input/at9852.augustus.gff (0 missing)
# Added 26816 genes from input/at9852.liftoff.protonly.gff (0 missing)
# Added 13962 genes from input/at9852.pasa.fix.gff (0 missing)
# Added 15879 genes from input/at9852.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	10734
# only_aug	6524
# aug_liftoff_cds_agree_use_liftoff	5738
# aug_liftoff_cds_disagree_use_aug	3479
# only_liftoff	1884
# TOO_HARD	1490
# pasa_liftoff_cds_agree_use_pasa	1461
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	858
# pasa_cds_different_use_pasa	745
# aug_pasa_cds_agree_use_pasa	510
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	60
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	50
#
#
# at9879
# loci at input/at9879_loci.bed
# N loci: 34209
# Added 32643 genes from input/at9879.augustus.gff (0 missing)
# Added 26870 genes from input/at9879.liftoff.protonly.gff (0 missing)
# Added 32611 genes from input/at9879.pasa.fix.gff (0 missing)
# Added 16274 genes from input/at9879.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	16281
# aug_pasa_cds_agree_use_pasa	11766
# only_liftoff	1966
# TOO_HARD	1556
# pasa_liftoff_cds_agree_use_pasa	1488
# pasa_cds_different_use_pasa	848
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	746
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	46
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	20
#
#
# at9883
# loci at input/at9883_loci.bed
# N loci: 33811
# Added 32338 genes from input/at9883.augustus.gff (0 missing)
# Added 26944 genes from input/at9883.liftoff.protonly.gff (0 missing)
# Added 13990 genes from input/at9883.pasa.fix.gff (0 missing)
# Added 15734 genes from input/at9883.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	10694
# only_aug	7186
# aug_liftoff_cds_agree_use_liftoff	5949
# aug_liftoff_cds_disagree_use_aug	3506
# only_liftoff	1953
# pasa_liftoff_cds_agree_use_pasa	1524
# TOO_HARD	1380
# pasa_cds_different_use_pasa	798
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	728
# aug_pasa_cds_agree_use_pasa	515
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	62
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	44
#
#
# at9900
# loci at input/at9900_loci.bed
# N loci: 33472
# Added 31856 genes from input/at9900.augustus.gff (0 missing)
# Added 26865 genes from input/at9900.liftoff.protonly.gff (0 missing)
# Added 14796 genes from input/at9900.pasa.fix.gff (0 missing)
# Added 16754 genes from input/at9900.tama-v2.fix.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_pasa_cds_agree_use_pasa	11241
# only_aug	6785
# aug_liftoff_cds_agree_use_liftoff	5210
# aug_liftoff_cds_disagree_use_aug	3375
# only_liftoff	1955
# pasa_liftoff_cds_agree_use_pasa	1609
# TOO_HARD	1562
# pasa_cds_different_use_pasa	839
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	765
# aug_pasa_cds_agree_use_pasa	563
# aug_liftoff_pasa_agree_subgene_tama_merges_use_pasa	74
# aug_pasa_cds_disagree_but_cds_too_long_for_isoseq_use_aug	48

# %%
for acc in "${dl20[@]}"
do

    echo
    echo
    echo ${acc}
   
    grep "^$acc" \
        /ebio/abt6_projects7/dliso/dlis/leon_pipeline/output/v2/collapse_tama/${acc}_augustus_transdecoder/${acc}_transcripts.fasta.transdecoder.genome.gff3 \
     | sed -e '1 i\##gff-version 3' \
     >input/${acc}.transdecoder.gff
    files=( input/${acc}.augustus.gff  input/${acc}.liftoff.protonly.gff input/${acc}.pasa.fix.gff input/${acc}.tama-v2.fix.gff
    input/${acc}.transdecoder.gff)
    
    rm -fr ~/public_html/gffuuu/${acc}/
    mkdir -p ~/public_html/gffuuu/${acc}/
    blsl genigvjs --outdir ~/public_html/gffuuu/${acc}/  \
                --reference ~/dl20/assembly-and-annotation/output/01_assembly/01_pansn-named/${acc}.scaffolds-v2.3.fasta \
                "${files[@]}" \
                output/${acc}_sad.gff3 \
                output/${acc}_decisions.bed \
                output/${acc}_happy.gff3
done
# Out:
# at6923
#
#
# at6929
#
#
# at7143
#
#
# at8285
#
#
# at9104
#
#
# at9336
#
#
# at9503
#
#
# at9578
#
#
# at9744
#
#
# at9762
#
#
# at9806
#
#
# at9830
#
#
# at9847
#
#
# at9852
#
#
# at9879
#
#
# at9883
#
#
# at9900

# %%
for acc in at6137
do
    grep 'Note=protein_coding_gene' input/${acc}.scaffolds-v2.3_liftoff_polished.gff3_polished.fix.gff3  | grep -Po "\tID=[^;]+" | cut -f 2 -d = >input/${acc}_tairpconly.txt 
    grep -f input/${acc}_tairpconly.txt input/${acc}.scaffolds-v2.3_liftoff_polished.gff3_polished.fix.gff3  > input/${acc}.liftoff.protonly.gff
    
    annots=( input/${acc}.augustus.gff  input/${acc}.liftoff.protonly.gff )

    for file in "${annots[@]}"
    do
        (head -n 1 $file | grep -q '^##gff-version') || sed -i -e '1 i\##gff-version 3' $file
    done
    
    cat "${annots[@]}" |
        sortBed -i - |
        mergeBed -i - -s -c 7 -o distinct >input/${acc}_loci.bed
        
    python3 gffuuuu.py \
        --sad output/${acc}_sad.gff3 \
        --decisions output/${acc}_decisions.bed \
        --happy output/${acc}_happy.gff3 \
        --loci input/${acc}_loci.bed \
        "${annots[@]}"
    
    
    rm -fr ~/public_html/gffuuu/${acc}/
    mkdir -p ~/public_html/gffuuu/${acc}/
    blsl genigvjs --outdir ~/public_html/gffuuu/${acc}/  \
                --reference ~/dl20/assembly-and-annotation/output/01_assembly/01_pansn-named/${acc}.scaffolds-v2.3.fasta \
                "${files[@]}" \
                output/${acc}_sad.gff3 \
                output/${acc}_decisions.bed \
                output/${acc}_happy.gff3
done
# Out:
# loci at input/at6137_loci.bed
# N loci: 33514
# Added 31972 genes from input/at6137.augustus.gff (0 missing)
# Added 26838 genes from input/at6137.liftoff.protonly.gff (0 missing)
# Now scan over loci...
# Now write GFFs...
# DONE! Stats follow
#
# aug_liftoff_cds_agree_use_liftoff	17936
# only_aug	7128
# aug_liftoff_cds_disagree_use_aug	5752
# only_liftoff	1972
# TOO_HARD	699
# liftoff_augustus_agree_subgene_isoseq_merges_use_liftoff	143

# %%
sed -i -e 's/\tNone\t/\t.\t/g' output/*.gff3

# %%
for acc in "${dl20[@]}" at6137
do
    intersectBed -wa -a output/${acc}_decisions.bed \
        -b ../assembly-and-annotation/output/04_analyses_with_fixed_at9879/NLRs_list/${acc}.nlrs.genes.augustus.bed \
        -s \
        > output/${acc}_nlr_decisions.bed
done

# %%
d
