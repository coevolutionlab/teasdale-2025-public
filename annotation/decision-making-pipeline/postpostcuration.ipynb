# %%
conda activate dl20

# %%
rm -f tmp/9852.hp.agat.gff3
agat_convert_sp_gxf2gxf.pl \
    -g post-curation/at9852_hodgepodgemerged.gff3 \
    -o tmp/9852.hp.agat.gff3
sort -i tmp/9852.hp.agat.gff3 -k 1,1 -k 4,4n -s -o tmp/9852.hp.agat.sort.gff3
# Out:
# Using standard /tmp/global2/kmurray/conda/envs/dl20/lib/perl5/site_perl/auto/share/dist/AGAT/config.yaml file
# ********************************************************************************
# *                              - Start parsing -                               *
# ********************************************************************************
# -------------------------- parse options and metadata --------------------------
# => Accessing the feature_levels YAML file
# Using standard /tmp/global2/kmurray/conda/envs/dl20/lib/perl5/site_perl/auto/share/dist/AGAT/feature_levels.yaml file
# => Attribute used to group features when no Parent/ID relationship exists (i.e common tag):
# 	* locus_tag
# 	* gene_id
# => merge_loci option deactivated
# => Machine information:
# 	This script is being run by perl v5.32.1
# 	Bioperl location being used: /tmp/global2/kmurray/conda/envs/dl20/lib/perl5/site_perl/Bio/
# 	Operating system being used: linux
# => Accessing Ontology
# ...
