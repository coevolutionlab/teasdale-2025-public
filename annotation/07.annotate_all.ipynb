# %% [markdown]
# # annotate-all

# %%
dl20=(
at6137 at6923 at6929 at7143
at8285 at9104 at9336 at9503
at9578 at9744 at9762 at9806
at9830 at9847 at9852 at9879
at9883 at9900
)
mkdir -p tmp/log

# %%
for accession in "${dl20[@]}"
do
    for masking in all-repeats-masked reduced-te-masked telo-centro-rdna-masked unmasked
    do
        OUT="output/02_annotation/03_augustus-reannotation/${accession}~${masking}/"
        mkdir -p $OUT
        
        if [ -e $OUT/02_augustus/${accession}~${masking}_augustus_spp-arabidopsis.gff3 ]
        then
            echo "SKIP    ${accession}_${masking}"
            continue
        fi
        
        echo "SUB     ${accession}_${masking}"
        qsub -N an_${accession}_${masking}  \
            -o tmp/log/ \
            -pe parallel 8 \
            -l h_vmem=6G \
            -l h_rt=18:00:00 \
            -j y \
            -S /bin/bash \
            -cwd \
            -m beas   <<EOF
        source ~/.bashrc;
        export PATH="$HOME/.local/bin:$PATH"
        papermill \
            --request-save-on-cell-execute \
            --autosave-cell-every 60 \
            -p ACCESSION "$accession" \
            -p SCAFFOLD_TITLE "${masking}" \
            -p SCAFFOLDS "output/01_assembly/02_masked/${accession}.scaffolds.${masking}.fasta" \
            -p OUTDIR "${OUT}" \
            do_annotate_full_per_fasta.ipynb \
            "${OUT}/annotation_output.ipynb"
            
EOF
    done
done
# Out:
# SKIP    at6137_all-repeats-masked
# SKIP    at6137_reduced-te-masked
# SKIP    at6137_telo-centro-rdna-masked
# SKIP    at6137_unmasked
# SKIP    at6923_all-repeats-masked
# SKIP    at6923_reduced-te-masked
# SKIP    at6923_telo-centro-rdna-masked
# SKIP    at6923_unmasked
# SKIP    at6929_all-repeats-masked
# SKIP    at6929_reduced-te-masked
# SKIP    at6929_telo-centro-rdna-masked
# SKIP    at6929_unmasked
# SKIP    at7143_all-repeats-masked
# SKIP    at7143_reduced-te-masked
# SKIP    at7143_telo-centro-rdna-masked
# SKIP    at7143_unmasked
# SKIP    at8285_all-repeats-masked
# SKIP    at8285_reduced-te-masked
# SKIP    at8285_telo-centro-rdna-masked
# SKIP    at8285_unmasked
# SKIP    at9104_all-repeats-masked
# SKIP    at9104_reduced-te-masked
# SKIP    at9104_telo-centro-rdna-masked
# SKIP    at9104_unmasked
# SKIP    at9336_all-repeats-masked
# SKIP    at9336_reduced-te-masked
# SKIP    at9336_telo-centro-rdna-masked
# SKIP    at9336_unmasked
# SKIP    at9503_all-repeats-masked
# SKIP    at9503_reduced-te-masked
# SKIP    at9503_telo-centro-rdna-masked
# SKIP    at9503_unmasked
# SKIP    at9578_all-repeats-masked
# SKIP    at9578_reduced-te-masked
# SKIP    at9578_telo-centro-rdna-masked
# SKIP    at9578_unmasked
# SKIP    at9744_all-repeats-masked
# SKIP    at9744_reduced-te-masked
# SKIP    at9744_telo-centro-rdna-masked
# SUB     at9744_unmasked
# Your job 9760665 ("an_at9744_unmasked") has been submitted
# SKIP    at9762_all-repeats-masked
# SKIP    at9762_reduced-te-masked
# SKIP    at9762_telo-centro-rdna-masked
# SKIP    at9762_unmasked
# SKIP    at9806_all-repeats-masked
# SKIP    at9806_reduced-te-masked
# SKIP    at9806_telo-centro-rdna-masked
# SKIP    at9806_unmasked
# SKIP    at9830_all-repeats-masked
# SKIP    at9830_reduced-te-masked
# SKIP    at9830_telo-centro-rdna-masked
# SKIP    at9830_unmasked
# SKIP    at9847_all-repeats-masked
# SKIP    at9847_reduced-te-masked
# SKIP    at9847_telo-centro-rdna-masked
# SKIP    at9847_unmasked
# SKIP    at9852_all-repeats-masked
# SKIP    at9852_reduced-te-masked
# SKIP    at9852_telo-centro-rdna-masked
# SKIP    at9852_unmasked
# SKIP    at9879_all-repeats-masked
# SKIP    at9879_reduced-te-masked
# SKIP    at9879_telo-centro-rdna-masked
# SKIP    at9879_unmasked
# SKIP    at9883_all-repeats-masked
# SKIP    at9883_reduced-te-masked
# SKIP    at9883_telo-centro-rdna-masked
# SKIP    at9883_unmasked
# SKIP    at9900_all-repeats-masked
# SKIP    at9900_reduced-te-masked
# SKIP    at9900_telo-centro-rdna-masked
# SKIP    at9900_unmasked
