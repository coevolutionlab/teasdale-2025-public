# %%
dl20=(
at6137 at6923 at6929 at7143 at8285 at9104 at9336 at9503
at9578 at9744 at9762 at9806 at9830 at9847 at9852 at9879
at9883 at9900
)
mkdir -p output/02_annotation/01_original-annotation-merged
mkdir -p tmp/02_annotation/01_original-annotation-merged
conda activate dl20-gff

# %%
for accession in "${dl20[@]}"
do

    echo "preprep TEs for $accession"
    grep "^$accession" input/2022-07-16_curated-repeat-annotation-adri/pangenome.fasta.mod.EDTA.TEanno.gff3 | \
    ./src/pansn-rename -R '_' -d '#' -D '_' -m cat \
        -r output/01_assembly/01_pansn-named/${accession}.scaffolds-v2.3.fasta.fai \
        -o tmp/02_annotation/01_original-annotation-merged/${accession}_all-repeats.gff3 \
        -

    # Genomtools outputs a *lot* of bullshit logging, which will crash jupyter as it's actually longer
    # than the original gffs. So, we save the log files alongside the outputs, in case they are ever useful.

    ( ./src/liftoff-gff3 \
        < tmp/02_annotation/01_original-annotation-merged/${accession}_all-repeats.gff3 \
    | gt gff3 -sort -tidy -retainids -force \
        -o output/02_annotation/01_original-annotation-merged/${accession}.all-repeats.gff3 \
    && echo "done gt repeats for $accession" \
    ) |& tee output/02_annotation/01_original-annotation-merged/${accession}.all-repeats.gff3.log | \
    grep -vi '^warning' || true

    ( ./src/liftoff-gff3 \
        < output/01_assembly/01_pansn-named/${accession}.augustus-v2.3.gff3 \
    | gt gff3 -sort -tidy -retainids -force \
        -o output/02_annotation/01_original-annotation-merged/${accession}.augustus-v2.3.gff3 \
    &&  echo "done gt augustus for $accession" \
    ) |& tee output/02_annotation/01_original-annotation-merged/${accession}.augustus-v2.3.gff3.log | \
    grep -vi '^warning'

    ( ./src/liftoff-gff3 \
        < output/01_assembly/01_pansn-named/${accession}.liftoff-v2.3.gff \
    | gt gff3 -sort -tidy -retainids -force \
        -o output/02_annotation/01_original-annotation-merged/${accession}.liftoff-v2.3.gff3 \
    && echo "done gt liftoff for $accession" \
    ) |& tee output/02_annotation/01_original-annotation-merged/${accession}.liftoff-v2.3.gff3.log | \
    grep -vi '^warning' || true

    # The nlrparser output is a special one in that it isn't *really* a gff.
    # It's a bed with an extra column that kinda works as a gff if you squint.
    # So, just make it a bed. It's a gff enough to used 1-based coordinates though
    # so fix that up.

    awk 'BEGIN{FS=OFS="\t"}{print $1, $3-1, $4, $5, $6}' \
        < output/01_assembly/01_pansn-named/${accession}.nlrparser-completeNLRs-v2.3.gff \
        > output/02_annotation/01_original-annotation-merged/${accession}.nlrparser-completeNLRs-v2.3.bed

    ( ./src/liftoff-gff3 \
        < output/01_assembly/01_pansn-named/${accession}.nlrome-liftoff-v2.3.gff \
    | gt gff3 -sort -tidy -retainids -force \
        -o output/02_annotation/01_original-annotation-merged/${accession}.nlrome-liftoff-v2.3.gff3 \
    && echo "done gt nlrome for $accession" \
    ) |& tee output/02_annotation/01_original-annotation-merged/${accession}.nlrome-liftoff-v2.3.gff3.log | \
    grep -vi '^warning'

done
# Out:
# preprep TEs for at6137
# done gt repeats for at6137
# done gt augustus for at6137
# Fixed empty attribute (;=;) 194529 times
# done gt liftoff for at6137
# done gt nlrome for at6137
# preprep TEs for at6923
# done gt repeats for at6923
# done gt augustus for at6923
# Fixed empty attribute (;=;) 194815 times
# done gt liftoff for at6923
# done gt nlrome for at6923
# preprep TEs for at6929
# done gt repeats for at6929
# done gt augustus for at6929
# Fixed empty attribute (;=;) 194402 times
# done gt liftoff for at6929
# done gt nlrome for at6929
# preprep TEs for at7143
# done gt repeats for at7143
# done gt augustus for at7143
# Fixed empty attribute (;=;) 194770 times
# done gt liftoff for at7143
# done gt nlrome for at7143
# preprep TEs for at8285
# done gt repeats for at8285
# done gt augustus for at8285
# Fixed empty attribute (;=;) 194597 times
# done gt liftoff for at8285
# done gt nlrome for at8285
# preprep TEs for at9104
# done gt repeats for at9104
# done gt augustus for at9104
# Fixed empty attribute (;=;) 194633 times
# done gt liftoff for at9104
# done gt nlrome for at9104
# preprep TEs for at9336
# done gt repeats for at9336
# done gt augustus for at9336
# Fixed empty attribute (;=;) 194640 times
# done gt liftoff for at9336
# done gt nlrome for at9336
# preprep TEs for at9503
# done gt repeats for at9503
# done gt augustus for at9503
# Fixed empty attribute (;=;) 194890 times
# done gt liftoff for at9503
# done gt nlrome for at9503
# preprep TEs for at9578
# done gt repeats for at9578
# done gt augustus for at9578
# Fixed empty attribute (;=;) 194624 times
# done gt liftoff for at9578
# done gt nlrome for at9578
# preprep TEs for at9744
# done gt repeats for at9744
# done gt augustus for at9744
# Fixed empty attribute (;=;) 194910 times
# done gt liftoff for at9744
# done gt nlrome for at9744
# preprep TEs for at9762
# done gt repeats for at9762
# done gt augustus for at9762
# Fixed empty attribute (;=;) 194555 times
# done gt liftoff for at9762
# done gt nlrome for at9762
# preprep TEs for at9806
# done gt repeats for at9806
# done gt augustus for at9806
# Fixed empty attribute (;=;) 194932 times
# done gt liftoff for at9806
# done gt nlrome for at9806
# preprep TEs for at9830
# done gt repeats for at9830
# done gt augustus for at9830
# Fixed empty attribute (;=;) 194627 times
# done gt liftoff for at9830
# done gt nlrome for at9830
# preprep TEs for at9847
# done gt repeats for at9847
# done gt augustus for at9847
# Fixed empty attribute (;=;) 194722 times
# done gt liftoff for at9847
# done gt nlrome for at9847
# preprep TEs for at9852
# done gt repeats for at9852
# done gt augustus for at9852
# Fixed empty attribute (;=;) 194559 times
# done gt liftoff for at9852
# done gt nlrome for at9852
# preprep TEs for at9879
# done gt repeats for at9879
# done gt augustus for at9879
# Fixed empty attribute (;=;) 194279 times
# done gt liftoff for at9879
# done gt nlrome for at9879
# preprep TEs for at9883
# done gt repeats for at9883
# done gt augustus for at9883
# Fixed empty attribute (;=;) 194654 times
# done gt liftoff for at9883
# done gt nlrome for at9883
# preprep TEs for at9900
# done gt repeats for at9900
# done gt augustus for at9900
# Fixed empty attribute (;=;) 194578 times
# done gt liftoff for at9900
# done gt nlrome for at9900
