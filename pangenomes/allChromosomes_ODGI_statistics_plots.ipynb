# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import odgi

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 odgi.__version__
#
# AttributeError: module 'odgi' has no attribute '__version__'

# %%
nodeLengthChr=pd.read_table("chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3_odgi_stats/chr3_node_length.txt",
                           names=['node', 'node-length'])

# %%
nodeLengthChr.head()
# Out:
#    node  node-length
# 0     1         9996
# 1     2            9
# 2     3            5
# 3     4            1
# 4     5            1

# %%
plt.figure(figsize=(20,4))
sns.lineplot(nodeLengthChr, x=nodeLengthChr["node"], y=nodeLengthChr["node-length"])
# Out:
# <Axes: xlabel='node', ylabel='node-length'>

# %%
node
