mkdir -p neighborhoods/chr5/cluster_og
mkdir -p neighborhoods/chr5/cluster_gfa
mkdir -p neighborhoods/chr5/cluster_allPathCoordinates
mkdir -p neighborhoods/chr5/cluster_viz
mkdir -p neighborhoods/chr5/cluster_pav
mkdir -p neighborhoods/chr5/cluster_similarity
mkdir -p neighborhoods/chr5/cluster_jumps
mkdir -p neighborhoods/chr5/cluster_heaps
mkdir -p neighborhoods/chr5/cluster_panacus
# Out:
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# : 1

# %%
inputOdgi=chr5_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr5.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og
outdir=neighborhoods/chr5

while read a b c d; 
do   
    r_path=$(echo "${a}:${b}-${c}")
    r=${r_path}
    nh=${d}
    outprefix=${nh}.region

    ########################## view the pangenome graph of the region ######################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.bm.png \
    -x 1000 \
    -bm \
    -t 20 \
    -P \
    -r ${r}
    ########################## Node Strandedness ############################################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.z.png \
    -x 1000 \
    -z \
    -t 20 \
    -P \
    -r ${r}
    
    ############################################ extract the region ############################################
    odgi extract \
    -i $inputOdgi \
    -r ${r} \
    --threads 24 -P \
    -d 100000 \
    -c 1  \
    -o $outdir/cluster_og/${outprefix}.og 
    
    ########################### get the coordinates in all the accessions ########################################
    odgi paths -L \
    -i $outdir/cluster_og/${outprefix}.og  \
    > $outdir/cluster_allPathCoordinates/${outprefix}.allPathsCoordinates.txt
    
    ########################### for bandage plot #################################################################
    odgi view -i $outdir/cluster_og/${outprefix}.og  \
    -g > $outdir/cluster_gfa/${outprefix}.gfa
    
    ########################### Individual path-based PAV comparisons ############################################
    while read line;
    do
        r=${line}
        echo $r|cut -d ':' -f1,2 >tmp1
        echo $r|cut -d ':' -f3|sed "s/-/\t/g" >tmp2
        paste tmp1 tmp2 > \
        $outdir/cluster_allPathCoordinates/${outprefix}.${line}.bed && rm tmp1 && rm tmp2
        
        odgi pav \
        -i $inputOdgi \
        -t 24 \
        -b $outdir/cluster_allPathCoordinates/${outprefix}.${line}.bed > \
        $outdir/cluster_pav/${outprefix}.${line}.pav.txt
        
    done < $outdir/cluster_allPathCoordinates/${outprefix}.allPathsCoordinates.txt
    
    ########################### Node Jumps in Neighborhood ######################################################
    ## for each node how many jumps it has taken
    cat $outdir/cluster_gfa/${outprefix}.gfa \
    |grep "^L" \
    |awk '{print $1,$2,$4,$4-$2}'\
    |sed "s/ /\t/g" \
    > $outdir/cluster_jumps/${outprefix}.nodeJumps.txt
    
    
    ########################### Node Degrees ############################################################
    odgi \
    degree \
    -i $outdir/cluster_og/${outprefix}.og \
    -t 24 \
    -d \
    -r ${r} > $outdir/cluster_jumps/${outprefix}.nodeDegrees.txt
    
    
    ########################### Node Depth ###############################################################
    odgi \
    depth \
    -i $outdir/cluster_og/${outprefix}.og \
    -t 24 \
    -d \
    -r ${r} > $outdir/cluster_jumps/${outprefix}.nodeDepth.txt
    
    ########################### Distance between different Paths (accessions) for the region #############
    odgi \
    similarity \
    -i $outdir/cluster_og/${outprefix}.og \
    -t 24 \
    -d > $outdir/cluster_similarity/${outprefix}.distance.txt
    
    ###### Pangenome Graph Growth  Heaps' Law #########

    odgi sort \
    -i $outdir/cluster_og/${outprefix}.og \
    -p Y \
    -O \
    -t 24 \
    -P \
    -o $outdir/cluster_og/${outprefix}.optimized_sorted.og 
    
    for i in {1..18}
    do
    seq -w 1 ${i} > $outdir/cluster_heaps/pathGroup${i}.groups.txt
    done
    
    
    for i in {1..18}
    do
    odgi paths -i $outdir/cluster_og/${outprefix}.optimized_sorted.og \
    -L|sort -R|head -n ${i} > $outdir/cluster_heaps/pathGroup${i}.txt 
    done
    
    for i in {1..18}
    do
    paste $outdir/cluster_heaps/pathGroup${i}.txt $outdir/cluster_heaps/pathGroup${i}.groups.txt > tmp
    mv tmp $outdir/cluster_heaps/pathGroup${i}.txt
    done
    
    for i in {1..18}
    do
        odgi \
        heaps \
        -i $outdir/cluster_og/${outprefix}.optimized_sorted.og \
        -t 24 \
        -S \
        -d 2 \
        -n 100 \
        -p $outdir/cluster_heaps/pathGroup${i}.txt \
        > $outdir/cluster_heaps/${outprefix}.pathGroup${i}.optimized_sorted.heaps.txt
    done
    
    
    ########################## Panacus ##############################
    parentDir=$outdir
    
    conda activate /u/gshirsekar/conda-envs/pggb #panacus is installed here

    grep '^P' ${parentDir}/cluster_gfa/${outprefix}.gfa|cut -f2|sed "s/_.*//g" > ${parentDir}/cluster_panacus/${outprefix}.groupNames.txt
    grep '^P' ${parentDir}/cluster_gfa/${outprefix}.gfa|cut -f2> ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt
    
    paste ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt \
    ${parentDir}/cluster_panacus/${outprefix}.groupNames.txt \
    > ${parentDir}/cluster_panacus/${outprefix}.groups.txt
    
    sed -i "s/_1_chr5/#1#chr5/g" ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt 
    sed -i "s/_1_chr5/#1#chr5/g" ${parentDir}/cluster_panacus/${outprefix}.groups.txt
    
    
    cat ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt |cut -f1,3 -d ":" > \
    ${parentDir}/cluster_panacus/${outprefix}.newPathNames.txt
    
    paste ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt \
    ${parentDir}/cluster_panacus/${outprefix}.newPathNames.txt > ${parentDir}/cluster_panacus/tmp
    
    while read a b ; do sed -i "s/${a}/${b}/" ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt ; done < ${parentDir}/cluster_panacus/tmp
    while read a b ; do sed -i "s/${a}/${b}/" ${parentDir}/cluster_panacus/${outprefix}.groups.txt ; done < ${parentDir}/cluster_panacus/tmp
    cp ${parentDir}/cluster_gfa/${outprefix}.gfa ${parentDir}/cluster_panacus/${outprefix}.ed.gfa
    sed -i "s/_1_chr5/#1#chr5/g" ${parentDir}/cluster_panacus/${outprefix}.ed.gfa
    
    while read a b ; do sed -i "s/${a}/${b}/g" ${parentDir}/cluster_panacus/${outprefix}.ed.gfa ; done < ${parentDir}/cluster_panacus/tmp 
    
    panacus histgrowth -t24 -q 0,0.1,0.5,1 -l 1,2,3,17 -g ${parentDir}/cluster_panacus/${outprefix}.groups.txt \
    -s ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt \
    ${parentDir}/cluster_panacus/${outprefix}.ed.gfa > ${parentDir}/cluster_panacus/${outprefix}.histgrowth.txt
    
    panacus-visualize -e ${parentDir}/cluster_panacus/${outprefix}.histgrowth.txt > ${parentDir}/cluster_panacus/${outprefix}.histgrowth.node.pdf

done < neighborhoods/all_neighborhoods_at9852.chr5.txt
# Out:
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.71585e+06, 1.73318e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 17.331
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.71585e+06, 1.73318e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 17.331
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 4.75e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.06e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.39e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 6.06e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.98e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.16e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.19704e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 6.26e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.00181e+06, 2.01726e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 15.449
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.00181e+06, 2.01726e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 15.449
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 4.68e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.53e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.45e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 4.64e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.98e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.69101e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.19e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.35134e+06, 4.36284e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 11.491
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.35134e+06, 4.36284e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 11.491
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 4.59e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.60e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.21e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 4.93e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.48e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.43083e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.63e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.73766e+06, 4.75775e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 20.093
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.73766e+06, 4.75775e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 20.093
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 4.65e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.20e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.75e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 2.82e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.34e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (4.64477e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 2.57e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [7.092e+06, 7.10227e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 10.264
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [7.092e+06, 7.10227e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 10.264
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 4.11e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.45e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.55e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 3.03e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.18e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.79984e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3.51e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [7.19852e+06, 7.39961e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 201.088
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [7.19852e+06, 7.39961e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 201.088
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 4.05e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.32e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.21e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 3.98e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.83e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.10505e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3.67e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [7.47936e+06, 7.50205e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 22.688
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [7.47936e+06, 7.50205e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 22.688
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 4.38e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.68e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.33e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 7.20e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.72e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (7.07353e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 7.45e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [9.3937e+06, 9.40507e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 11.372
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [9.3937e+06, 9.40507e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 11.372
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 3.95e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.77e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.59e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.80e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.69e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.07498e-05 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 2.00e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.75344e+07, 2.75761e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 41.696
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.75344e+07, 2.75761e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 41.696
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.19e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.52e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.63e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.18e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.76e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (2.51759e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.35e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.8901e+07, 2.89911e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 90.087
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.8901e+07, 2.89911e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 90.087
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.20e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.48e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.52e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.96e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.62e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.68656e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.48e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.06699e+07, 3.08584e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 188.526
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.06699e+07, 3.08584e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 188.526
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.24e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.09e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.44e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 4.70e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.78e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.16e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (2.34876e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 4.19e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.11248e+07, 3.11608e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 36.012
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.11248e+07, 3.11608e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 36.012
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.51e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.53e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.58e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 2.20e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.13e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (7.5061e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 2.43e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.64355e+07, 3.64966e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 61.145
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.64355e+07, 3.64966e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 61.145
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.33e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.39e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.71e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.64e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.72e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.42722e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.61e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.70191e+07, 3.70994e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 80.331
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.70191e+07, 3.70994e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 80.331
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.36e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.45e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.43e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 2.36e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.58e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (6.49114e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 2.42e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.73921e+07, 3.74364e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 44.31
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.73921e+07, 3.74364e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 44.31
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.15e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.19e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.78e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.13e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.18e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (4.15697e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.05e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.75051e+07, 3.77362e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 231.158
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.75051e+07, 3.77362e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 231.158
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.28e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.13e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.48e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 7.59e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 6.63e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.14e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (7.00737e-09 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3