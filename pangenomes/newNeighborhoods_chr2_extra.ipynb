# %%
conda activate pggb_fatica
# Out:
# (pggb_fatica)
# : 1

# %% [markdown]
# ## round1 (9879)

# %%
chromosomeName=$(odgi paths -L -i chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og|grep "9879")
echo $chromosomeName

## here input should be a bed file of leftmost NLRs start and rightmost NLRs stop for the cluster (group of NLRs)
sed -i "s/at9879_1_chr2/${chromosomeName}/g" neighborhoods/extra/chr2_eCompound_round1.bed
while read chromosome start stop compoundName
do

    odgi \
    position \
    -i chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -b <(echo -e "${chromosome}\t${start}\t${stop}") \
    -v 

done < neighborhoods/extra/chr2_eCompound_round1.bed |cut -f1,4,5|cut -d ',' -f1,3|sed 's/+//g'|sed 's/,//g' > neighborhoods/extra/chr2_eCompound_round1.graph.bed

rm tmp*
while read chromosome gstart gstop
do
    echo ${chromosome} >> tmp3
    
    # take fifth leftmost node with depth.uniq=18 and length greater than 100 as left anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "start=${gstart}" '($1<start)'|tail -n 5|head -n1|cut -f1 >> tmp1
    
    # take fifth rightmost node with depth.uniq=18 and length greater than 100 as right anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "stop=${gstop}" '($1>stop)'|head -n 5|tail -n1|cut -f1 >> tmp2

done < neighborhoods/extra/chr2_eCompound_round1.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr2_eNeighborhood_round1.graph.bed

rm tmp*
while read chromosome nStart nStop
do
    echo ${chromosome} >> tmp3

    odgi position \
    -i chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStart} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp1

    odgi position \
    -i chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStop} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp2
done < neighborhoods/extra/chr2_eNeighborhood_round1.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr2_eNeighborhood_round1.coordinates.bed



inputOdgi=chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og
outdir=neighborhoods/chr2
count=0
while read a b c; 
do
    ((count+=1))   
    r_path=$(echo "${a}:${b}-${c}")
    r=${r_path}
    nh=$(echo "e_r1_nh_${count}")
    outprefix=${nh}.region

    ########################## view the pangenome graph of the region ######################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.bm.png \
    -x 1000 \
    -bm \
    -t 20 \
    -P \
    -r ${r}
    ########################## Node Strandedness ############################################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.z.png \
    -x 1000 \
    -z \
    -t 20 \
    -P \
    -r ${r}
    
    ############################################ extract the region ############################################
    odgi extract \
    -i $inputOdgi \
    -r ${r} \
    --threads 24 -P \
    -d 100000 \
    -c 1  \
    -o $outdir/${outprefix}.og 
    
    ########################### get the coordinates in all the accessions ########################################
    odgi paths -L \
    -i $outdir/${outprefix}.og  \
    > $outdir/${outprefix}.allPathsCoordinates.txt
done < neighborhoods/extra/chr2_eNeighborhood_round1.coordinates.bed


for i in {1..4}
do
sed -i "s/$/\tchr2_e_r1_nh${i}/g" neighborhoods/chr2/e_r1_nh_${i}.region.allPathsCoordinates.txt
done

for i in {1..4}
do 
sed -i "s/chr2_e_r1_nh${i}/chr2_e_r1_nh0${i}/g" neighborhoods/chr2/e_r1_nh_${i}.region.allPathsCoordinates.txt
done


for i in {1..4}
do 
cut -d ":" -f1,3 neighborhoods/chr2/e_r1_nh_${i}.region.allPathsCoordinates.txt |sed "s/:/\t/g"|sed "s/-/\t/g" > neighborhoods/chr2/e_r1_nh_${i}.region.allPathsCoordinates.bed
done
# Out:
# (pggb_fatica)
# at9879_1_chr2:0-24779077
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.58167e+06, 4.81352e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 231.854
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.58167e+06, 4.81352e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 231.854
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.01e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 1.86e+00/s elapsed: 00:00:00:09 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 1.05e+01/s elapsed: 00:00:00:01 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 3 (max 3) 100.00% @ 2.69e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.33e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.94e+01/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 1.40e+02/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.83726e+06, 4.84133e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 4.07
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.83726e+06, 4.84133e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 4.07
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.12e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.51e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.29e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.21e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.60e+01/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 1.67e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [6.10079e+06, 3.69656e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 30864.8
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [6.10079e+06, 3.69656e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 30864.8
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.71e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 8.96e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 1.19e+01/s elapsed: 00:00:00:01 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 3 (max 3) 100.00% @ 1.16e+01/s elapsed: 00:00:00:01 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 8.55e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.22e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 1.39e+01/s elapsed: 00:00:00:01 remain: 00:00:00:00
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.25739e+07, 3.25907e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 16.797
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.25739e+07, 3.25907e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 16.797
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 2.53e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 9.34e+00/s elapsed: 00:00:00:01 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 1.19e+01/s elapsed: 00:00:00:01 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 2.16e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.70e+01/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 1.49e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# : 1

# %% [markdown]
# ## round2 (9852)

# %%
chromosomeName=$(odgi paths -L -i chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og|grep "9852")
echo $chromosomeName

## here input should be a bed file of leftmost NLRs start and rightmost NLRs stop for the cluster (group of NLRs)
sed -i "s/at9852_1_chr2/${chromosomeName}/g" neighborhoods/extra/chr2_eCompound_round2.bed
while read chromosome start stop compoundName
do

    odgi \
    position \
    -i chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -b <(echo -e "${chromosome}\t${start}\t${stop}") \
    -v 

done < neighborhoods/extra/chr2_eCompound_round2.bed |cut -f1,4,5|cut -d ',' -f1,3|sed 's/+//g'|sed 's/,//g' > neighborhoods/extra/chr2_eCompound_round2.graph.bed
# Out:
# (pggb_fatica)
# at9852_1_chr2:0-23396451
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# : 1

# %%
rm tmp*
while read chromosome gstart gstop
do
    echo ${chromosome} >> tmp3
    
    # take fifth leftmost node with depth.uniq=18 and length greater than 100 as left anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "start=${gstart}" '($1<start)'|tail -n 5|head -n1|cut -f1 >> tmp1
    
    # take fifth rightmost node with depth.uniq=18 and length greater than 100 as right anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "stop=${gstop}" '($1>stop)'|head -n 5|tail -n1|cut -f1 >> tmp2

done < neighborhoods/extra/chr2_eCompound_round2.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr2_eNeighborhood_round2.graph.bed

rm tmp*
while read chromosome nStart nStop
do
    echo ${chromosome} >> tmp3

    odgi position \
    -i chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStart} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp1

    odgi position \
    -i chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStop} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp2
done < neighborhoods/extra/chr2_eNeighborhood_round2.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr2_eNeighborhood_round2.coordinates.bed



inputOdgi=chr2_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr2.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og
outdir=neighborhoods/chr2
count=0
while read a b c; 
do
    ((count+=1))   
    r_path=$(echo "${a}:${b}-${c}")
    r=${r_path}
    nh=$(echo "e_r2_nh_${count}")
    outprefix=${nh}.region

    ########################## view the pangenome graph of the region ######################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.bm.png \
    -x 1000 \
    -bm \
    -t 20 \
    -P \
    -r ${r}
    ########################## Node Strandedness ############################################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.z.png \
    -x 1000 \
    -z \
    -t 20 \
    -P \
    -r ${r}
    
    ############################################ extract the region ############################################
    odgi extract \
    -i $inputOdgi \
    -r ${r} \
    --threads 24 -P \
    -d 100000 \
    -c 1  \
    -o $outdir/${outprefix}.og 
    
    ########################### get the coordinates in all the accessions ########################################
    odgi paths -L \
    -i $outdir/${outprefix}.og  \
    > $outdir/${outprefix}.allPathsCoordinates.txt
done < neighborhoods/extra/chr2_eNeighborhood_round2.coordinates.bed


for i in 1
do
sed -i "s/$/\tchr2_e_r2_nh${i}/g" neighborhoods/chr2/e_r2_nh_${i}.region.allPathsCoordinates.txt
done

for i in 1
do 
sed -i "s/chr2_e_r2_nh${i}/chr2_e_r2_nh0${i}/g" neighborhoods/chr2/e_r2_nh_${i}.region.allPathsCoordinates.txt
done


for i in 1
do 
cut -d ":" -f1,3 neighborhoods/chr2/e_r2_nh_${i}.region.allPathsCoordinates.txt |sed "s/:/\t/g"|sed "s/-/\t/g" > neighborhoods/chr2/e_r2_nh_${i}.region.allPathsCoordinates.bed
done
# Out:
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.58515e+06, 3.63183e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 34733.2
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.58515e+06, 3.63183e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 34733.2
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 4.66e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.87e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.17e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 3 (max 3) 100.00% @ 4.19e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 4.58e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 4.68e+00/s elapsed: 00:00:00:10 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.57e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# : 1
