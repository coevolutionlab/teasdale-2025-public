# %%
conda activate pggb_fatica
# Out:
# (pggb_fatica)
# : 1

# %% [markdown]
# ## round1 (9762)

# %%
chromosomeName=$(odgi paths -L -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og|grep "9762")
echo $chromosomeName

## here input should be a bed file of leftmost NLRs start and rightmost NLRs stop for the cluster (group of NLRs)
sed -i "s/at9762_1_chr3/${chromosomeName}/g" neighborhoods/extra/chr3_eCompound_round1.bed
while read chromosome start stop compoundName
do

    odgi \
    position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -b <(echo -e "${chromosome}\t${start}\t${stop}") \
    -v 

done < neighborhoods/extra/chr3_eCompound_round1.bed |cut -f1,4,5|cut -d ',' -f1,3|sed 's/+//g'|sed 's/,//g' > neighborhoods/extra/chr3_eCompound_round1.graph.bed

rm tmp*
while read chromosome gstart gstop
do
    echo ${chromosome} >> tmp3
    
    # take fifth leftmost node with depth.uniq=18 and length greater than 100 as left anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "start=${gstart}" '($1<start)'|tail -n 5|head -n1|cut -f1 >> tmp1
    
    # take fifth rightmost node with depth.uniq=18 and length greater than 100 as right anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "stop=${gstop}" '($1>stop)'|head -n 5|tail -n1|cut -f1 >> tmp2

done < neighborhoods/extra/chr3_eCompound_round1.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr3_eNeighborhood_round1.graph.bed

rm tmp*
while read chromosome nStart nStop
do
    echo ${chromosome} >> tmp3

    odgi position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStart} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp1

    odgi position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStop} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp2
done < neighborhoods/extra/chr3_eNeighborhood_round1.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr3_eNeighborhood_round1.coordinates.bed



inputOdgi=chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og
outdir=neighborhoods/chr3
count=0
while read a b c; 
do
    ((count+=1))   
    r_path=$(echo "${a}:${b}-${c}")
    r=${r_path}
    nh=$(echo "e_r1_nh_${count}")
    outprefix=${nh}.region

    ########################## view the pangenome graph of the region ######################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.bm.png \
    -x 1000 \
    -bm \
    -t 20 \
    -P \
    -r ${r}
    ########################## Node Strandedness ############################################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.z.png \
    -x 1000 \
    -z \
    -t 20 \
    -P \
    -r ${r}
    
    ############################################ extract the region ############################################
    odgi extract \
    -i $inputOdgi \
    -r ${r} \
    --threads 24 -P \
    -d 100000 \
    -c 1  \
    -o $outdir/${outprefix}.og 
    
    ########################### get the coordinates in all the accessions ########################################
    odgi paths -L \
    -i $outdir/${outprefix}.og  \
    > $outdir/${outprefix}.allPathsCoordinates.txt
done < neighborhoods/extra/chr3_eNeighborhood_round1.coordinates.bed


for i in {1..2}
do
sed -i "s/$/\tchr3_e_r1_nh${i}/g" neighborhoods/chr3/e_r1_nh_${i}.region.allPathsCoordinates.txt
done

for i in {1..2}
do 
sed -i "s/chr3_e_r1_nh${i}/chr3_e_r1_nh0${i}/g" neighborhoods/chr3/e_r1_nh_${i}.region.allPathsCoordinates.txt
done


for i in {1..2}
do 
cut -d ":" -f1,3 neighborhoods/chr3/e_r1_nh_${i}.region.allPathsCoordinates.txt |sed "s/:/\t/g"|sed "s/-/\t/g" > neighborhoods/chr3/e_r1_nh_${i}.region.allPathsCoordinates.bed
done
# Out:
# (pggb_fatica)
# at9762_1_chr3:0-27262250
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.94495e+07, 3.96616e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 212.062
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.94495e+07, 3.96616e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 212.062
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 2.23e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.74e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.03e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 4.23e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 2.11e+00/s elapsed: 00:00:00:24 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.97897e+07, 4.00581e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 268.437
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.97897e+07, 4.00581e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 268.437
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 2.21e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.30e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.78e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 7.08e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.61e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# : 1

# %% [markdown]
# ## round2 (9852)

# %%
chromosomeName=$(odgi paths -L -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og|grep "9852")
echo $chromosomeName

## here input should be a bed file of leftmost NLRs start and rightmost NLRs stop for the cluster (group of NLRs)
sed -i "s/at9852_1_chr3/${chromosomeName}/g" neighborhoods/extra/chr3_eCompound_round2.bed
while read chromosome start stop compoundName
do

    odgi \
    position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -b <(echo -e "${chromosome}\t${start}\t${stop}") \
    -v 

done < neighborhoods/extra/chr3_eCompound_round2.bed |cut -f1,4,5|cut -d ',' -f1,3|sed 's/+//g'|sed 's/,//g' > neighborhoods/extra/chr3_eCompound_round2.graph.bed
# Out:
# (pggb_fatica)
# at9852_1_chr3:0-26358531
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# : 1

# %%
rm tmp*
while read chromosome gstart gstop
do
    echo ${chromosome} >> tmp3
    
    # take fifth leftmost node with depth.uniq=18 and length greater than 100 as left anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "start=${gstart}" '($1<start)'|tail -n 5|head -n1|cut -f1 >> tmp1
    
    # take fifth rightmost node with depth.uniq=18 and length greater than 100 as right anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "stop=${gstop}" '($1>stop)'|head -n 5|tail -n1|cut -f1 >> tmp2

done < neighborhoods/extra/chr3_eCompound_round2.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr3_eNeighborhood_round2.graph.bed

rm tmp*
while read chromosome nStart nStop
do
    echo ${chromosome} >> tmp3

    odgi position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStart} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp1

    odgi position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStop} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp2
done < neighborhoods/extra/chr3_eNeighborhood_round2.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr3_eNeighborhood_round2.coordinates.bed



inputOdgi=chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og
outdir=neighborhoods/chr3
count=0
while read a b c; 
do
    ((count+=1))   
    r_path=$(echo "${a}:${b}-${c}")
    r=${r_path}
    nh=$(echo "e_r2_nh_${count}")
    outprefix=${nh}.region

    ########################## view the pangenome graph of the region ######################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.bm.png \
    -x 1000 \
    -bm \
    -t 20 \
    -P \
    -r ${r}
    ########################## Node Strandedness ############################################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.z.png \
    -x 1000 \
    -z \
    -t 20 \
    -P \
    -r ${r}
    
    ############################################ extract the region ############################################
    odgi extract \
    -i $inputOdgi \
    -r ${r} \
    --threads 24 -P \
    -d 100000 \
    -c 1  \
    -o $outdir/${outprefix}.og 
    
    ########################### get the coordinates in all the accessions ########################################
    odgi paths -L \
    -i $outdir/${outprefix}.og  \
    > $outdir/${outprefix}.allPathsCoordinates.txt
done < neighborhoods/extra/chr3_eNeighborhood_round2.coordinates.bed


for i in 1
do
sed -i "s/$/\tchr3_e_r2_nh${i}/g" neighborhoods/chr3/e_r2_nh_${i}.region.allPathsCoordinates.txt
done

for i in 1
do 
sed -i "s/chr3_e_r2_nh${i}/chr3_e_r2_nh0${i}/g" neighborhoods/chr3/e_r2_nh_${i}.region.allPathsCoordinates.txt
done


for i in 1
do 
cut -d ":" -f1,3 neighborhoods/chr3/e_r2_nh_${i}.region.allPathsCoordinates.txt |sed "s/:/\t/g"|sed "s/-/\t/g" > neighborhoods/chr3/e_r2_nh_${i}.region.allPathsCoordinates.bed
done
# Out:
# rm: cannot remove 'tmp*': No such file or directory
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.52137e+07, 1.56371e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 423.463
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.52137e+07, 1.56371e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 423.463
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 8.03e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 2.77e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 3.96e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.32e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.03e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.12e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# : 1

# %%
chromosomeName=$(odgi paths -L -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og|grep "9336")
echo $chromosomeName

## here input should be a bed file of leftmost NLRs start and rightmost NLRs stop for the cluster (group of NLRs)
sed -i "s/at9336_1_chr3/${chromosomeName}/g" neighborhoods/extra/chr3_eCompound_round3.bed
while read chromosome start stop compoundName
do

    odgi \
    position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -b <(echo -e "${chromosome}\t${start}\t${stop}") \
    -v 

done < neighborhoods/extra/chr3_eCompound_round3.bed |cut -f1,4,5|cut -d ',' -f1,3|sed 's/+//g'|sed 's/,//g' > neighborhoods/extra/chr3_eCompound_round3.graph.bed



rm tmp*
while read chromosome gstart gstop
do
    echo ${chromosome} >> tmp3
    
    # take fifth leftmost node with depth.uniq=18 and length greater than 100 as left anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "start=${gstart}" '($1<start)'|tail -n 5|head -n1|cut -f1 >> tmp1
    
    # take fifth rightmost node with depth.uniq=18 and length greater than 100 as right anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "stop=${gstop}" '($1>stop)'|head -n 5|tail -n1|cut -f1 >> tmp2

done < neighborhoods/extra/chr3_eCompound_round3.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr3_eNeighborhood_round3.graph.bed

rm tmp*
while read chromosome nStart nStop
do
    echo ${chromosome} >> tmp3

    odgi position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStart} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp1

    odgi position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStop} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp2
done < neighborhoods/extra/chr3_eNeighborhood_round3.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr3_eNeighborhood_round3.coordinates.bed



inputOdgi=chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og
outdir=neighborhoods/chr3
count=0
while read a b c; 
do
    ((count+=1))   
    r_path=$(echo "${a}:${b}-${c}")
    r=${r_path}
    nh=$(echo "e_r3_nh_${count}")
    outprefix=${nh}.region

    ########################## view the pangenome graph of the region ######################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.bm.png \
    -x 1000 \
    -bm \
    -t 20 \
    -P \
    -r ${r}
    ########################## Node Strandedness ############################################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.z.png \
    -x 1000 \
    -z \
    -t 20 \
    -P \
    -r ${r}
    
    ############################################ extract the region ############################################
    odgi extract \
    -i $inputOdgi \
    -r ${r} \
    --threads 24 -P \
    -d 100000 \
    -c 1  \
    -o $outdir/${outprefix}.og 
    
    ########################### get the coordinates in all the accessions ########################################
    odgi paths -L \
    -i $outdir/${outprefix}.og  \
    > $outdir/${outprefix}.allPathsCoordinates.txt
done < neighborhoods/extra/chr3_eNeighborhood_round3.coordinates.bed


for i in 1
do
sed -i "s/$/\tchr3_e_r3_nh${i}/g" neighborhoods/chr3/e_r3_nh_${i}.region.allPathsCoordinates.txt
done

for i in 1
do 
sed -i "s/chr3_e_r3_nh${i}/chr3_e_r3_nh0${i}/g" neighborhoods/chr3/e_r3_nh_${i}.region.allPathsCoordinates.txt
done


for i in 1
do 
cut -d ":" -f1,3 neighborhoods/chr3/e_r3_nh_${i}.region.allPathsCoordinates.txt |sed "s/:/\t/g"|sed "s/-/\t/g" > neighborhoods/chr3/e_r3_nh_${i}.region.allPathsCoordinates.bed
done
# Out:
# (pggb_fatica)
# at9336_1_chr3:0-27060997
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.90091e+07, 3.94814e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 472.287
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.90091e+07, 3.94814e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 472.287
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.54e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.85e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.21e+00/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.22e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 8.04e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.15e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# : 1

# %%
chromosomeName=$(odgi paths -L -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og|grep "9852")
echo $chromosomeName

## here input should be a bed file of leftmost NLRs start and rightmost NLRs stop for the cluster (group of NLRs)
sed -i "s/at9852_1_chr3/${chromosomeName}/g" neighborhoods/extra/test.bed
while read chromosome start stop compoundName
do

    odgi \
    position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -b <(echo -e "${chromosome}\t${start}\t${stop}") \
    -v 

done < neighborhoods/extra/test.bed |cut -f1,4,5|cut -d ',' -f1,3|sed 's/+//g'|sed 's/,//g' > neighborhoods/extra/test.graph.bed
# Out:
# at9852_1_chr3:0-26358531

# %%
rm tmp*
while read chromosome gstart gstop
do
    echo ${chromosome} >> tmp3
    
    # take fifth leftmost node with depth.uniq=18 and length greater than 100 as left anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "start=${gstart}" '($1<start)'|tail -n 5|head -n1|cut -f1 >> tmp1
    
    # take fifth rightmost node with depth.uniq=18 and length greater than 100 as right anchor for the neighborhood
    awk '($2>100)&&($4==18)' chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og.nodeDepthLength.txt|awk -v "stop=${gstop}" '($1>stop)'|head -n 5|tail -n1|cut -f1 >> tmp2

done < neighborhoods/extra/chr3_eCompound_round1.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr3_eNeighborhood_round1.graph.bed

rm tmp*
while read chromosome nStart nStop
do
    echo ${chromosome} >> tmp3

    odgi position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStart} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp1

    odgi position \
    -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og \
    -t 24 \
    -g ${nStop} \
    -r ${chromosome} |tail -n +2|cut -d ',' -f4,5|sed "s/,/\t/g"|cut -f1 >> tmp2
done < neighborhoods/extra/chr3_eNeighborhood_round1.graph.bed

paste tmp3 tmp1 tmp2 > neighborhoods/extra/chr3_eNeighborhood_round1.coordinates.bed



inputOdgi=chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og
outdir=neighborhoods/chr3
count=0
while read a b c; 
do
    ((count+=1))   
    r_path=$(echo "${a}:${b}-${c}")
    r=${r_path}
    nh=$(echo "e_r1_nh_${count}")
    outprefix=${nh}.region

    ########################## view the pangenome graph of the region ######################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.bm.png \
    -x 1000 \
    -bm \
    -t 20 \
    -P \
    -r ${r}
    ########################## Node Strandedness ############################################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.z.png \
    -x 1000 \
    -z \
    -t 20 \
    -P \
    -r ${r}
    
    ############################################ extract the region ############################################
    odgi extract \
    -i $inputOdgi \
    -r ${r} \
    --threads 24 -P \
    -d 100000 \
    -c 1  \
    -o $outdir/${outprefix}.og 
    
    ########################### get the coordinates in all the accessions ########################################
    odgi paths -L \
    -i $outdir/${outprefix}.og  \
    > $outdir/${outprefix}.allPathsCoordinates.txt
done < neighborhoods/extra/chr3_eNeighborhood_round1.coordinates.bed


for i in {1..2}
do
sed -i "s/$/\tchr3_e_r1_nh${i}/g" neighborhoods/chr3/e_r1_nh_${i}.region.allPathsCoordinates.txt
done

for i in {1..2}
do 
sed -i "s/chr3_e_r1_nh${i}/chr3_e_r1_nh0${i}/g" neighborhoods/chr3/e_r1_nh_${i}.region.allPathsCoordinates.txt
done


for i in {1..2}
do 
cut -d ":" -f1,3 neighborhoods/chr3/e_r1_nh_${i}.region.allPathsCoordinates.txt |sed "s/:/\t/g"|sed "s/-/\t/g" > neighborhoods/chr3/e_r1_nh_${i}.region.allPathsCoordinates.bed
done
