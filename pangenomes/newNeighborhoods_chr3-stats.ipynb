# %%
conda activate pggb_fatica
# Out:
# (pggb_fatica)
# : 1

# %%
chromosomeName=$(odgi paths -L -i chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og|grep "9852")
# Out:
# (pggb_fatica)
# : 1

# %%
cat neighborhoods/final/final_all_neighborhoods.chr3.bed|grep "at9852"|sed "s/at9852_1_chr3/${chromosomeName}/g" > neighborhoods/all_neighborhoods_at9852.chr3.txt
# Out:
# (pggb_fatica)
# : 1

# %%
cat neighborhoods/all_neighborhoods_at9852.chr3.txt
# Out:
# at9852_1_chr3:0-26358531	986433	998797	chr3_nh01
# at9852_1_chr3:0-26358531	1107258	1119128	chr3_nh02
# at9852_1_chr3:0-26358531	2288132	2298826	chr3_nh03
# at9852_1_chr3:0-26358531	4902984	4918561	chr3_nh04
# at9852_1_chr3:0-26358531	5371601	5375265	chr3_nh05
# at9852_1_chr3:0-26358531	9286719	9301993	chr3_nh06
# at9852_1_chr3:0-26358531	9699851	9705927	chr3_nh07
# at9852_1_chr3:0-26358531	11367510	11501535	chr3_e_r2_nh01-chr3_nh08
# at9852_1_chr3:0-26358531	18544551	18661770	chr3_e_r3_nh01
# at9852_1_chr3:0-26358531	18661770	18709065	chr3_e_r1_nh01
# at9852_1_chr3:0-26358531	18769451	18844464	chr3_e_r1_nh02
# at9852_1_chr3:0-26358531	18886349	19189268	chr3_nh09-chr3_nh10
# at9852_1_chr3:0-26358531	19965999	20073885	chr3_nh11
# at9852_1_chr3:0-26358531	21019447	21254834	chr3_nh12
# at9852_1_chr3:0-26358531	21644687	21684226	chr3_nh13
# at9852_1_chr3:0-26358531	21863615	21869798	chr3_nh14
# at9852_1_chr3:0-26358531	22047184	22061534	chr3_nh15
# (pggb_fatica)
# : 1

# %%
mkdir -p neighborhoods/chr3/cluster_og
mkdir -p neighborhoods/chr3/cluster_gfa
mkdir -p neighborhoods/chr3/cluster_allPathCoordinates
mkdir -p neighborhoods/chr3/cluster_viz
mkdir -p neighborhoods/chr3/cluster_pav
mkdir -p neighborhoods/chr3/cluster_similarity
mkdir -p neighborhoods/chr3/cluster_jumps
mkdir -p neighborhoods/chr3/cluster_heaps
mkdir -p neighborhoods/chr3/cluster_panacus
# Out:
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# : 1

# %%
inputOdgi=chr3_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr3.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og
outdir=neighborhoods/chr3

while read a b c d; 
do   
    r_path=$(echo "${a}:${b}-${c}")
    r=${r_path}
    nh=${d}
    outprefix=${nh}.region

    ########################## view the pangenome graph of the region ######################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.bm.png \
    -x 1000 \
    -bm \
    -t 20 \
    -P \
    -r ${r}
    ########################## Node Strandedness ############################################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.z.png \
    -x 1000 \
    -z \
    -t 20 \
    -P \
    -r ${r}
    
    ############################################ extract the region ############################################
    odgi extract \
    -i $inputOdgi \
    -r ${r} \
    --threads 24 -P \
    -d 100000 \
    -c 1  \
    -o $outdir/cluster_og/${outprefix}.og 
    
    ########################### get the coordinates in all the accessions ########################################
    odgi paths -L \
    -i $outdir/cluster_og/${outprefix}.og  \
    > $outdir/cluster_allPathCoordinates/${outprefix}.allPathsCoordinates.txt
    
    ########################### for bandage plot #################################################################
    odgi view -i $outdir/cluster_og/${outprefix}.og  \
    -g > $outdir/cluster_gfa/${outprefix}.gfa
    
    ########################### Individual path-based PAV comparisons ############################################
    while read line;
    do
        r=${line}
        echo $r|cut -d ':' -f1,2 >tmp1
        echo $r|cut -d ':' -f3|sed "s/-/\t/g" >tmp2
        paste tmp1 tmp2 > \
        $outdir/cluster_allPathCoordinates/${outprefix}.${line}.bed && rm tmp1 && rm tmp2
        
        odgi pav \
        -i $inputOdgi \
        -t 24 \
        -b $outdir/cluster_allPathCoordinates/${outprefix}.${line}.bed > \
        $outdir/cluster_pav/${outprefix}.${line}.pav.txt
        
    done < $outdir/cluster_allPathCoordinates/${outprefix}.allPathsCoordinates.txt
    
    ########################### Node Jumps in Neighborhood ######################################################
    ## for each node how many jumps it has taken
    cat $outdir/cluster_gfa/${outprefix}.gfa \
    |grep "^L" \
    |awk '{print $1,$2,$4,$4-$2}'\
    |sed "s/ /\t/g" \
    > $outdir/cluster_jumps/${outprefix}.nodeJumps.txt
    
    
    ########################### Node Degrees ############################################################
    odgi \
    degree \
    -i $outdir/cluster_og/${outprefix}.og \
    -t 24 \
    -d \
    -r ${r} > $outdir/cluster_jumps/${outprefix}.nodeDegrees.txt
    
    
    ########################### Node Depth ###############################################################
    odgi \
    depth \
    -i $outdir/cluster_og/${outprefix}.og \
    -t 24 \
    -d \
    -r ${r} > $outdir/cluster_jumps/${outprefix}.nodeDepth.txt
    
    ########################### Distance between different Paths (accessions) for the region #############
    odgi \
    similarity \
    -i $outdir/cluster_og/${outprefix}.og \
    -t 24 \
    -d > $outdir/cluster_similarity/${outprefix}.distance.txt
    
    ###### Pangenome Graph Growth  Heaps' Law #########

    odgi sort \
    -i $outdir/cluster_og/${outprefix}.og \
    -p Y \
    -O \
    -t 24 \
    -P \
    -o $outdir/cluster_og/${outprefix}.optimized_sorted.og 
    
    for i in {1..18}
    do
    seq -w 1 ${i} > $outdir/cluster_heaps/pathGroup${i}.groups.txt
    done
    
    
    for i in {1..18}
    do
    odgi paths -i $outdir/cluster_og/${outprefix}.optimized_sorted.og \
    -L|sort -R|head -n ${i} > $outdir/cluster_heaps/pathGroup${i}.txt 
    done
    
    for i in {1..18}
    do
    paste $outdir/cluster_heaps/pathGroup${i}.txt $outdir/cluster_heaps/pathGroup${i}.groups.txt > tmp
    mv tmp $outdir/cluster_heaps/pathGroup${i}.txt
    done
    
    for i in {1..18}
    do
        odgi \
        heaps \
        -i $outdir/cluster_og/${outprefix}.optimized_sorted.og \
        -t 24 \
        -S \
        -d 2 \
        -n 100 \
        -p $outdir/cluster_heaps/pathGroup${i}.txt \
        > $outdir/cluster_heaps/${outprefix}.pathGroup${i}.optimized_sorted.heaps.txt
    done
    
    
    ########################## Panacus ##############################
    parentDir=$outdir
    
    conda activate /u/gshirsekar/conda-envs/pggb #panacus is installed here

    grep '^P' ${parentDir}/cluster_gfa/${outprefix}.gfa|cut -f2|sed "s/_.*//g" > ${parentDir}/cluster_panacus/${outprefix}.groupNames.txt
    grep '^P' ${parentDir}/cluster_gfa/${outprefix}.gfa|cut -f2> ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt
    
    paste ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt \
    ${parentDir}/cluster_panacus/${outprefix}.groupNames.txt \
    > ${parentDir}/cluster_panacus/${outprefix}.groups.txt
    
    sed -i "s/_1_chr3/#1#chr3/g" ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt 
    sed -i "s/_1_chr3/#1#chr3/g" ${parentDir}/cluster_panacus/${outprefix}.groups.txt
    
    
    cat ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt |cut -f1,3 -d ":" > \
    ${parentDir}/cluster_panacus/${outprefix}.newPathNames.txt
    
    paste ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt \
    ${parentDir}/cluster_panacus/${outprefix}.newPathNames.txt > ${parentDir}/cluster_panacus/tmp
    
    while read a b ; do sed -i "s/${a}/${b}/" ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt ; done < ${parentDir}/cluster_panacus/tmp
    while read a b ; do sed -i "s/${a}/${b}/" ${parentDir}/cluster_panacus/${outprefix}.groups.txt ; done < ${parentDir}/cluster_panacus/tmp
    cp ${parentDir}/cluster_gfa/${outprefix}.gfa ${parentDir}/cluster_panacus/${outprefix}.ed.gfa
    sed -i "s/_1_chr3/#1#chr3/g" ${parentDir}/cluster_panacus/${outprefix}.ed.gfa
    
    while read a b ; do sed -i "s/${a}/${b}/g" ${parentDir}/cluster_panacus/${outprefix}.ed.gfa ; done < ${parentDir}/cluster_panacus/tmp 
    
    panacus histgrowth -t24 -q 0,0.1,0.5,1 -l 1,2,3,17 -g ${parentDir}/cluster_panacus/${outprefix}.groups.txt \
    -s ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt \
    ${parentDir}/cluster_panacus/${outprefix}.ed.gfa > ${parentDir}/cluster_panacus/${outprefix}.histgrowth.txt
    
    panacus-visualize -e ${parentDir}/cluster_panacus/${outprefix}.histgrowth.txt > ${parentDir}/cluster_panacus/${outprefix}.histgrowth.node.pdf

done < neighborhoods/all_neighborhoods_at9852.chr3.txt
# Out:
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.13402e+06, 1.1655e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 31.486
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.13402e+06, 1.1655e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 31.486
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.07e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.83e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.30e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 6.35e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 8.60e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.00401e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 4.70e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.30471e+06, 1.32312e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 18.407
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.30471e+06, 1.32312e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 18.407
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.01e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.14e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.84e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 3.11e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 8.00e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.15e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.39157e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3.62e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.80759e+06, 2.81969e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 12.105
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.80759e+06, 2.81969e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 12.105
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 9.86e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.85e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.15e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 3.13e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.70e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.8147e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3.44e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [5.97008e+06, 5.98644e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 16.371
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [5.97008e+06, 5.98644e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 16.371
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 8.57e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.87e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.76e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 5.70e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.58e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.03911e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 6.85e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [6.53789e+06, 6.54159e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 3.699
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [6.53789e+06, 6.54159e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 3.699
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 8.57e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.53e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.40e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 4.44e+02/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 8.90e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 3.39e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (0.000160231 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.44e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.15811e+07, 1.16012e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 20.151
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.15811e+07, 1.16012e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 20.151
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 6.34e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.94e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.05e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 8.01e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 8.60e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (5.899e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 9.19e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.22708e+07, 1.22792e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 8.421
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.22708e+07, 1.22792e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 8.421
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 6.42e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.31e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.75e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 2.99e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 8.71e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 3.95e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (5.7508e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 2.89e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.52137e+07, 1.56371e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 423.463
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [1.52137e+07, 1.56371e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 423.463
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 5.87e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.50e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.83e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.33e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 8.55e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.12e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (2.94344e-09 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.53e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.90091e+07, 3.94808e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 471.699
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.90091e+07, 3.94808e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 471.699
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.98e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.25e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.89e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.25e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.97e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.15e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.01929e-09 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.55e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.94495e+07, 3.96616e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 212.062
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.94495e+07, 3.96616e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 212.062
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.59e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.60e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.31e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 4.23e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.52e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.20249e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3.44e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.97897e+07, 4.00581e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 268.437
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.97897e+07, 4.00581e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 268.437
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.54e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.08e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 4.81e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 7.18e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.61e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.16e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (9.57223e-09 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.03e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.01539e+07, 4.33147e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 3160.82
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.01539e+07, 4.33147e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 3160.82
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.78e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.06e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.21e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 3.22e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.05e+00/s elapsed: 00:00:00:07 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 6.98e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.84287e-10 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.46e+07/s elapsed: 00:00:00:01 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.36492e+07, 4.3873e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 223.825
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.36492e+07, 4.3873e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 223.825
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.77e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.84e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 6.11e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 7.01e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.86e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.14e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (8.5433e-09 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 6.42e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.53552e+07, 5.21231e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 6767.95
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.53552e+07, 5.21231e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 6767.95
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.67e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.17e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.37e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 3 (max 3) 100.00% @ 5.43e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 8.03e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 8.03e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.15e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (5.41135e-09 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 4.75e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.62134e+07, 4.6271e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 57.604
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.62134e+07, 4.6271e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 57.604
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.54e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.29e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.20e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 2.04e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.57e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.82862e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3.00e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.64988e+07, 4.6509e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 10.21
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.64988e+07, 4.6509e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 10.21
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.99e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 4.93e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.55e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.40e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.51e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 3.25e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.61288e-05 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.75e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.67067e+07, 4.67215e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 14.85
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.67067e+07, 4.67215e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 14.85
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.47e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.24e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 5.84e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 3.20e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 7.58e+00/s elapsed: 00:00:00:06 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.23482e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3.85e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# (/u/gshirsekar/conda-envs/pggb)
# : 1
