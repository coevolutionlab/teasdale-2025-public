# %%
conda activate pggb_fatica
# Out:
# (pggb_fatica)
# : 1

# %%
chromosomeName=$(odgi paths -L -i chr4_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr4.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og|grep "9852")
# Out:
# (pggb_fatica)
# : 1

# %%
cat neighborhoods/final/final_all_neighborhoods.chr4.bed|grep "at9852"|sed "s/at9852_1_chr4/${chromosomeName}/g" > neighborhoods/all_neighborhoods_at9852.chr4.txt
# Out:
# (pggb_fatica)
# : 1

# %%
cat neighborhoods/all_neighborhoods_at9852.chr4.txt
# Out:
# at9852_1_chr4:0-24203097	1700501	1727126	chr4_e_r4_nh01
# at9852_1_chr4:0-24203097	2445970	2452378	chr4_e_r3_nh01
# at9852_1_chr4:0-24203097	2455797	2540938	chr4_nh01
# at9852_1_chr4:0-24203097	10948767	10982024	chr4_nh02
# at9852_1_chr4:0-24203097	11500339	11560875	chr4_e_r1_nh01
# at9852_1_chr4:0-24203097	12195399	12210412	chr4_e_r2_nh01
# at9852_1_chr4:0-24203097	12364417	12388850	chr4_nh04
# at9852_1_chr4:0-24203097	12479245	12499773	chr4_e_r1_nh02
# at9852_1_chr4:0-24203097	12792076	12836849	chr4_nh05
# at9852_1_chr4:0-24203097	13906683	14017133	chr4_nh06
# at9852_1_chr4:0-24203097	15114744	15329424	chr4_nh07
# at9852_1_chr4:0-24203097	16096947	16115246	chr4_nh08
# at9852_1_chr4:0-24203097	16271612	16322663	chr4_nh09
# at9852_1_chr4:0-24203097	16467673	16481949	chr4_nh10
# at9852_1_chr4:0-24203097	17231162	17255325	chr4_nh11
# at9852_1_chr4:0-24203097	17843912	17887958	chr4_nh12
# at9852_1_chr4:0-24203097	18827932	18835823	chr4_nh13
# at9852_1_chr4:0-24203097	19221428	19242388	chr4_nh14
# at9852_1_chr4:0-24203097	21648854	21660269	chr4_nh15
# at9852_1_chr4:0-24203097	22695976	22716750	chr4_nh16
# (pggb_fatica)
# : 1

# %%
mkdir -p neighborhoods/chr4/cluster_og
mkdir -p neighborhoods/chr4/cluster_gfa
mkdir -p neighborhoods/chr4/cluster_allPathCoordinates
mkdir -p neighborhoods/chr4/cluster_viz
mkdir -p neighborhoods/chr4/cluster_pav
mkdir -p neighborhoods/chr4/cluster_similarity
mkdir -p neighborhoods/chr4/cluster_jumps
mkdir -p neighborhoods/chr4/cluster_heaps
mkdir -p neighborhoods/chr4/cluster_panacus
# Out:
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# : 1

# %%
inputOdgi=chr4_cluster.p95.s5000.n17.k47.G700-900-1100.at9852.pggbRecommended/chr4.fasta.gz.856e650.e34d4cd.a91cbe1.smooth.final.og
outdir=neighborhoods/chr4

while read a b c d; 
do   
    r_path=$(echo "${a}:${b}-${c}")
    r=${r_path}
    nh=${d}
    outprefix=${nh}.region

    ########################## view the pangenome graph of the region ######################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.bm.png \
    -x 1000 \
    -bm \
    -t 20 \
    -P \
    -r ${r}
    ########################## Node Strandedness ############################################
    odgi viz \
    -i $inputOdgi \
    -o $outdir/${outprefix}.z.png \
    -x 1000 \
    -z \
    -t 20 \
    -P \
    -r ${r}
    
    ############################################ extract the region ############################################
    odgi extract \
    -i $inputOdgi \
    -r ${r} \
    --threads 24 -P \
    -d 100000 \
    -c 1  \
    -o $outdir/cluster_og/${outprefix}.og 
    
    ########################### get the coordinates in all the accessions ########################################
    odgi paths -L \
    -i $outdir/cluster_og/${outprefix}.og  \
    > $outdir/cluster_allPathCoordinates/${outprefix}.allPathsCoordinates.txt
    
    ########################### for bandage plot #################################################################
    odgi view -i $outdir/cluster_og/${outprefix}.og  \
    -g > $outdir/cluster_gfa/${outprefix}.gfa
    
    ########################### Individual path-based PAV comparisons ############################################
    while read line;
    do
        r=${line}
        echo $r|cut -d ':' -f1,2 >tmp1
        echo $r|cut -d ':' -f3|sed "s/-/\t/g" >tmp2
        paste tmp1 tmp2 > \
        $outdir/cluster_allPathCoordinates/${outprefix}.${line}.bed && rm tmp1 && rm tmp2
        
        odgi pav \
        -i $inputOdgi \
        -t 24 \
        -b $outdir/cluster_allPathCoordinates/${outprefix}.${line}.bed > \
        $outdir/cluster_pav/${outprefix}.${line}.pav.txt
        
    done < $outdir/cluster_allPathCoordinates/${outprefix}.allPathsCoordinates.txt
    
    ########################### Node Jumps in Neighborhood ######################################################
    ## for each node how many jumps it has taken
    cat $outdir/cluster_gfa/${outprefix}.gfa \
    |grep "^L" \
    |awk '{print $1,$2,$4,$4-$2}'\
    |sed "s/ /\t/g" \
    > $outdir/cluster_jumps/${outprefix}.nodeJumps.txt
    
    
    ########################### Node Degrees ############################################################
    odgi \
    degree \
    -i $outdir/cluster_og/${outprefix}.og \
    -t 24 \
    -d \
    -r ${r} > $outdir/cluster_jumps/${outprefix}.nodeDegrees.txt
    
    
    ########################### Node Depth ###############################################################
    odgi \
    depth \
    -i $outdir/cluster_og/${outprefix}.og \
    -t 24 \
    -d \
    -r ${r} > $outdir/cluster_jumps/${outprefix}.nodeDepth.txt
    
    ########################### Distance between different Paths (accessions) for the region #############
    odgi \
    similarity \
    -i $outdir/cluster_og/${outprefix}.og \
    -t 24 \
    -d > $outdir/cluster_similarity/${outprefix}.distance.txt
    
    ###### Pangenome Graph Growth  Heaps' Law #########

    odgi sort \
    -i $outdir/cluster_og/${outprefix}.og \
    -p Y \
    -O \
    -t 24 \
    -P \
    -o $outdir/cluster_og/${outprefix}.optimized_sorted.og 
    
    for i in {1..18}
    do
    seq -w 1 ${i} > $outdir/cluster_heaps/pathGroup${i}.groups.txt
    done
    
    
    for i in {1..18}
    do
    odgi paths -i $outdir/cluster_og/${outprefix}.optimized_sorted.og \
    -L|sort -R|head -n ${i} > $outdir/cluster_heaps/pathGroup${i}.txt 
    done
    
    for i in {1..18}
    do
    paste $outdir/cluster_heaps/pathGroup${i}.txt $outdir/cluster_heaps/pathGroup${i}.groups.txt > tmp
    mv tmp $outdir/cluster_heaps/pathGroup${i}.txt
    done
    
    for i in {1..18}
    do
        odgi \
        heaps \
        -i $outdir/cluster_og/${outprefix}.optimized_sorted.og \
        -t 24 \
        -S \
        -d 2 \
        -n 100 \
        -p $outdir/cluster_heaps/pathGroup${i}.txt \
        > $outdir/cluster_heaps/${outprefix}.pathGroup${i}.optimized_sorted.heaps.txt
    done
    
    
    ########################## Panacus ##############################
    parentDir=$outdir
    
    conda activate /u/gshirsekar/conda-envs/pggb #panacus is installed here

    grep '^P' ${parentDir}/cluster_gfa/${outprefix}.gfa|cut -f2|sed "s/_.*//g" > ${parentDir}/cluster_panacus/${outprefix}.groupNames.txt
    grep '^P' ${parentDir}/cluster_gfa/${outprefix}.gfa|cut -f2> ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt
    
    paste ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt \
    ${parentDir}/cluster_panacus/${outprefix}.groupNames.txt \
    > ${parentDir}/cluster_panacus/${outprefix}.groups.txt
    
    sed -i "s/_1_chr4/#1#chr4/g" ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt 
    sed -i "s/_1_chr4/#1#chr4/g" ${parentDir}/cluster_panacus/${outprefix}.groups.txt
    
    
    cat ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt |cut -f1,3 -d ":" > \
    ${parentDir}/cluster_panacus/${outprefix}.newPathNames.txt
    
    paste ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt \
    ${parentDir}/cluster_panacus/${outprefix}.newPathNames.txt > ${parentDir}/cluster_panacus/tmp
    
    while read a b ; do sed -i "s/${a}/${b}/" ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt ; done < ${parentDir}/cluster_panacus/tmp
    while read a b ; do sed -i "s/${a}/${b}/" ${parentDir}/cluster_panacus/${outprefix}.groups.txt ; done < ${parentDir}/cluster_panacus/tmp
    cp ${parentDir}/cluster_gfa/${outprefix}.gfa ${parentDir}/cluster_panacus/${outprefix}.ed.gfa
    sed -i "s/_1_chr4/#1#chr4/g" ${parentDir}/cluster_panacus/${outprefix}.ed.gfa
    
    while read a b ; do sed -i "s/${a}/${b}/g" ${parentDir}/cluster_panacus/${outprefix}.ed.gfa ; done < ${parentDir}/cluster_panacus/tmp 
    
    panacus histgrowth -t24 -q 0,0.1,0.5,1 -l 1,2,3,17 -g ${parentDir}/cluster_panacus/${outprefix}.groups.txt \
    -s ${parentDir}/cluster_panacus/${outprefix}.pathNames.txt \
    ${parentDir}/cluster_panacus/${outprefix}.ed.gfa > ${parentDir}/cluster_panacus/${outprefix}.histgrowth.txt
    
    panacus-visualize -e ${parentDir}/cluster_panacus/${outprefix}.histgrowth.txt > ${parentDir}/cluster_panacus/${outprefix}.histgrowth.node.pdf

done < neighborhoods/all_neighborhoods_at9852.chr4.txt
# Out:
# (pggb_fatica)
# (pggb_fatica)
# (pggb_fatica)
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.81842e+06, 2.89723e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 78.812
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.81842e+06, 2.89723e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 78.812
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 4.52e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.99e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 6.90e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 2.42e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.02e+01/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.13e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (6.59151e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 2.57e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.21984e+06, 4.23603e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 16.188
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.21984e+06, 4.23603e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 16.188
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 4.20e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.39e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 6.40e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 3.12e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 9.61e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.52002e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3.73e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.23956e+06, 4.43529e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 195.735
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [4.23956e+06, 4.43529e+06]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 195.735
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 3.88e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.34e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 6.46e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 8.95e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 9.91e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.13e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.91212e-09 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 4.45e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.17684e+07, 2.18107e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 42.29
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.17684e+07, 2.18107e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 42.29
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.77e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.04e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 7.43e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.53e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.10e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (9.60885e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.79e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.3163e+07, 2.34562e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 293.212
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.3163e+07, 2.34562e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 293.212
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.43e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.85e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 7.04e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 2.88e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.04e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.16e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (5.44626e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 2.26e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.45593e+07, 2.45932e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 33.921
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.45593e+07, 2.45932e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 33.921
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.27e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.52e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 7.69e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 9.64e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.04e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.8789e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.25e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.484e+07, 2.4875e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 34.94
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.484e+07, 2.4875e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 34.94
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.52e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.19e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 6.59e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 9.62e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 9.48e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (7.16969e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 7.86e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.502e+07, 2.50583e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 38.33
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.502e+07, 2.50583e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 38.33
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.49e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.70e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 7.01e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.20e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 9.84e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.16e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (2.92184e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.13e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.55351e+07, 2.56331e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 97.973
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.55351e+07, 2.56331e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 97.973
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.30e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 7.48e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 6.99e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 2.84e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.08e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.15e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (5.28958e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 2.78e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.73844e+07, 2.75791e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 194.664
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.73844e+07, 2.75791e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 194.664
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.47e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.11e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 7.16e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 6.56e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 9.88e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.15e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (9.98003e-09 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3.40e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.91682e+07, 2.97516e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 583.341
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [2.91682e+07, 2.97516e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 583.341
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.20e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 5.91e+00/s elapsed: 00:00:00:03 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 7.13e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.43e+05/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.03e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.00e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (7.4011e-10 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.75e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.07689e+07, 3.08553e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 86.374
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.07689e+07, 3.08553e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 86.374
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.42e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.61e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 6.92e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 2.31e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.00e+01/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.14e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (9.9013e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.84e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.10025e+07, 3.12308e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 228.315
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.10025e+07, 3.12308e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 228.315
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.16e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.14e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 6.86e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 4.36e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.03e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.17e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (3.98723e-08 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 3.22e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.14172e+07, 3.14495e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 32.236
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.14172e+07, 3.14495e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 32.236
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.15e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.63e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 8.30e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 8.99e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.06e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (4.34539e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.00e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.29044e+07, 3.29357e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 31.29
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.29044e+07, 3.29357e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 31.29
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.16e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.05e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 6.97e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 6.25e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 9.96e+00/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.01008e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 6.74e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.37688e+07, 3.38577e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 88.909
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.37688e+07, 3.38577e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 88.909
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.32e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.25e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 6.68e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.18e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.08e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (2.55076e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.36e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:54: RuntimeWarning: overflow encountered in power
#   return fit(X, Y, lambda x, *y: y[0]*x**y[1])
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.49536e+07, 3.49698e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 16.184
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.49536e+07, 3.49698e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 16.184
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.36e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 7.08e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 7.41e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.83e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.16e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 2.80e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.01424e-05 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 2.22e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.54698e+07, 3.55427e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 72.991
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.54698e+07, 3.55427e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 72.991
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.36e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.64e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 7.09e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 3.34e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.08e+01/s elapsed: 00:00:00:04 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (5.00478e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 2.52e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.83663e+07, 3.83796e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 13.346
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.83663e+07, 3.83796e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 13.346
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.11e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.53e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 7.03e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 4.91e+03/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.00e+01/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (1.3972e-06 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 5.71e+06/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.95789e+07, 3.96255e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 46.678
# [odgi::viz] image width: 1000
# [odgi::viz] Path range to pangenomic range conversion.
# [odgi::viz] Visualizing the graph in the pangenomic range [3.95789e+07, 3.96255e+07]
# [odgi::viz] Binned mode
# [odgi::viz] bin width: 46.678
# [odgi::viz] image width: 1000
# [odgi::extract] expansion and adding connecting edges
# [odgi::extract] extracting path ranges 100.00% @ 1.36e+00/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 1 (max 3) 100.00% @ 6.74e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] merge subpaths closer than 100000 bps - iteration 2 (max 3) 100.00% @ 7.40e+00/s elapsed: 00:00:00:02 remain: 00:00:00:00
# [odgi::extract] adding connecting edges 100.00% @ 1.22e+04/s elapsed: 00:00:00:00 remain: 00:00:00:00
# [odgi::extract] adding subpaths 100.00% @ 1.00e+01/s elapsed: 00:00:00:05 remain: 00:00:00:00
# [odgi::extract] checking missing edges and empty subpaths 100.00% @ 7.18e+01/s elapsed: 00:00:00:00 remain: 00:00:00:00
# path_sgd_zipf_space_max: 100
# path_sgd_zipf_max_number_of_distributions: 101
# [odgi::path_linear_sgd] calculating linear SGD schedule (2.40764e-07 1 100 0 0.01)
# [odgi::path_linear_sgd] calculating zetas for 102 zipf distributions
# [odgi::path_linear_sgd] 1D path-guided SGD: 100.00% @ 1.32e+07/s elapsed: 00:00:00:00 remain: 00:00:00:00
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:107: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_yticklabels(calibrate_yticks_text(yticks))
# /u/gshirsekar/conda-envs/pggb/bin/panacus-visualize:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_yticklabels(calibrate_yticks_text(yticks))
# (/u/gshirsekar/conda-envs/pggb)
# : 1
